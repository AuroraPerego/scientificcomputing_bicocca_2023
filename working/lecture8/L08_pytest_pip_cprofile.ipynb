# %% [markdown]
# # Exercises
#
# For the exams work on at least two of the these three exercises

# %% [markdown]
# ## Q2: My own test
#
# - Pick a piece of python code that you like (your own PhD project, or take one of the exercises from this class). Implement a unit test and a regression test.
# - Put it under git version control, and write a github action that runs the tests at every commit.
# - Edit the github options to make sure the code *cannot* be committed if the tests fail (that's a common thing for big projects with many collaborations, nobody is allowed to break the code)
#
# [repository: xtd, branch: exam](https://github.com/AuroraPerego/xtd/tree/exam)

# %% [markdown]
# ## Q4: It's over Anakin, I have the high ground. I hate you!
#
# Pick a piece of your code that your really hate.  You hate it because it's soooooo slooooow.
# - Profile it.
# - Find the culprit
# - Rewrite that bottleneck making a better use of numpy arrays, or jitting it with Numba.
# - Enjoy your faster code
#
# **You underestimate my power**.

# %%
import awkward as ak
import numpy as np
import uproot as uproot

# %%
C = 29.9792458 #cm/ns

# %%
filename = 'histo_SinglePi_24fc_1hit_recTime.root'
file = uproot.open(filename)

# %%
file.keys()
# Out:
# ['ticlDumper;1',
#  'ticlDumper/rechits;11',
#  'ticlDumper/rechits;10',
#  'ticlDumper/tracksters;1',
#  'ticlDumper/clusters;1',
#  'ticlDumper/trackstersMerged;1',
#  'ticlDumper/associations;1',
#  'ticlDumper/simtrackstersSC;1',
#  'ticlDumper/simtrackstersCP;1']

# %%
simtrackstersSC = file["ticlDumper/simtrackstersSC"]
tracksters  = file["ticlDumper/tracksters"]
associations = file["ticlDumper/associations"]
clusters = file["ticlDumper/clusters"]

# %%
cluster_hits_with_time = clusters["cluster_number_of_hits_with_time"].array()

# %%
SC_boundx        = simtrackstersSC["boundaryX"].array()
SC_boundy        = simtrackstersSC["boundaryY"].array()
SC_boundz        = simtrackstersSC["boundaryZ"].array()
SC_bx            = simtrackstersSC["barycenter_x"].array()
SC_by            = simtrackstersSC["barycenter_y"].array()
SC_bz            = simtrackstersSC["barycenter_z"].array()
SC_boundary_time = simtrackstersSC["timeBoundary"].array()
SC_CALO_time     = simtrackstersSC["time"].array()
SC_CALO_timeErr  = simtrackstersSC["timeError"].array()
SC_trackIdx      = simtrackstersSC["trackIdx"].array()
SC_vt            = simtrackstersSC["vertices_time"].array()
SC_vtErr         = simtrackstersSC["vertices_timeErr"].array()
SC_vi            = simtrackstersSC["vertices_indexes"].array()
SC_vx            = simtrackstersSC["vertices_x"].array()
SC_vy            = simtrackstersSC["vertices_y"].array()
SC_vz            = simtrackstersSC["vertices_z"].array()

# %%
assoc_reco2sim = associations.arrays(["tsCLUE3D_recoToSim_SC_sharedE",
"tsCLUE3D_recoToSim_SC_score",
"tsCLUE3D_recoToSim_SC"])

# %%
ts3D = tracksters.arrays(["barycenter_x",
"barycenter_y",
"barycenter_z",
"time",
"timeError",
"vertices_x",
"vertices_y",
"vertices_z",
"vertices_time",
"vertices_indexes"])

# %% [markdown]
# ## recoTracksters time validation

# %%
def distance(x1,y1,z1,x2,y2,z2):
    return ((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)**0.5

def project_lc_to_pca(point, segment_start, segment_end):
    """
    `lc` is a 1D NumPy array of length 3 representing the point;
    `segment_start` and `segment_end` are 1D NumPy arrays of length 3 representing the start and end points of the line segment. 
    The function returns the minimum distance between the point and the line segment and the closest point on this segment.
    """
    segment_vector = segment_end - segment_start
    #print(segment_vector)
    point_vector = point - segment_start
    #print(point_vector)
    if not np.any(segment_vector):
        projection = 0
    else:
        projection = np.dot(point_vector, segment_vector) / np.dot(segment_vector, segment_vector)

    closest_point = segment_start + projection * segment_vector
    return np.linalg.norm(point - closest_point), closest_point

def computeCaloTime(ev, vx, vy, vz, vt, vi, LChitTime, bx, by, bz, NMIN =3, MR=3):
    n_ts = 0
    time_ts = 0
    for i, t in enumerate(vt):
        nHitsWithTime = LChitTime[vi[i]]
        if t != -99 and project_lc_to_pca(np.array([vx[i], vy[i], vz[i]]), np.array([0.,0.,0.]), np.array([bx, by, bz]))[0] < MR and nHitsWithTime >= NMIN:
            n_ts+=1
            if np.abs(bz)< np.abs(vz[i]):
                time_ts += t - distance(bx, by, bz, vx[i], vy[i], vz[i])/C
            else:
                time_ts += t + distance(bx, by, bz, vx[i], vy[i], vz[i])/C
    if n_ts == 0:
        return -99.
    else:
        return time_ts/n_ts
    return -99.

def compute_residuals_r2s(NMIN = 3):
    residui=[]
    for ev, (recoToSim_index_ev, recoToSim_score_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev, LChitTime) in enumerate(zip(assoc_reco2sim.tsCLUE3D_recoToSim_SC, 
    assoc_reco2sim.tsCLUE3D_recoToSim_SC_score, ts3D.barycenter_x, ts3D.barycenter_y, ts3D.barycenter_z, ts3D.vertices_x, ts3D.vertices_y, ts3D.vertices_z, ts3D.vertices_time, 
    ts3D.vertices_indexes, cluster_hits_with_time)):
        for r2s_score, r2s_idx, bx, by, bz, vx, vy, vz, vt, vi in zip(recoToSim_score_ev, recoToSim_index_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev):
            t = computeCaloTime(ev, vx, vy, vz, vt, vi, LChitTime, bx, by, bz, NMIN)
            si = r2s_idx[np.argmin(r2s_score)]
            boundt = SC_boundary_time[ev][si]
            if np.min(r2s_score) < 0.35 and boundt != -99 and t != -99:
                boundx = SC_boundx[ev][si]
                boundy = SC_boundy[ev][si]
                boundz = SC_boundz[ev][si]
                deltaT = t - boundt
                deltaS = distance(boundx, boundy, boundz, bx, by, bz)
                results = deltaT - deltaS / C
                residui.append(results)
    return residui

# %%
import cProfile, pstats
profiler = cProfile.Profile()
profiler.enable()
res = compute_residuals_r2s()
profiler.disable()
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
# Out:
#          26118634 function calls (25501428 primitive calls) in 51.060 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   51.060   25.530 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3400(run_code)
#         2    0.000    0.000   51.060   25.530 {built-in method builtins.exec}
#         1    0.000    0.000   51.060   51.060 /tmp/ipykernel_1306/2534407993.py:4(<module>)
#         1    0.360    0.360   51.060   51.060 /tmp/ipykernel_1306/1682533672.py:39(compute_residuals_r2s)
#    544948    2.644    0.000   34.426    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:578(__getitem__)
#     18050    0.690    0.000   32.083    0.002 /tmp/ipykernel_1306/1682533672.py:22(computeCaloTime)
# 1089896/544948    1.369    0.000   27.767    0.000 {built-in method builtins.hasattr}
# 544958/544948    4.009    0.000   26.534    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:1071(__getattr__)
#    544958   19.511    0.000   19.511    0.000 {built-in method builtins.dir}
#    893619    1.154    0.000    9.743    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:505(wrap)
#    371732    1.491    0.000    8.595    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:545(__iter__)
#    156561    1.183    0.000    7.944    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:197(__init__)
# 214232/178132    0.499    0.000    5.830    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    156561    0.261    0.000    5.288    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:352(behavior)
#    156561    2.016    0.000    5.026    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:222(arrayclass)
#     36100    0.047    0.000    4.497    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:1417(__array_function__)
#     36100    0.093    0.000    4.450    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_connect/_numpy.py:31(array_function)
#    626244    0.793    0.000    3.581    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/json/__init__.py:299(loads)
# 36100/18050    0.072    0.000    3.289    0.000 <__array_function__ internals>:177(argmin)
#     18050    0.165    0.000    3.134    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/reducers.py:691(argmin)
#    544948    2.037    0.000    2.851    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:74(exception_suffix)
#   5604216    1.786    0.000    2.651    0.000 {built-in method builtins.isinstance}
#    626244    1.126    0.000    2.542    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/json/decoder.py:332(decode)
#     35508    0.588    0.000    2.128    0.000 /tmp/ipykernel_1306/1682533672.py:4(project_lc_to_pca)
#     18050    0.132    0.000    2.010    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/structure.py:2791(fill_none)
#     72200    0.168    0.000    1.391    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/convert.py:1859(to_layout)
# 36100/18050    0.053    0.000    1.357    0.000 <__array_function__ internals>:177(amin)
#     18050    0.078    0.000    1.209    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/reducers.py:501(min)
#     18050    0.066    0.000    1.076    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/convert.py:42(from_numpy)
#     36100    0.241    0.000    1.016    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:564(completely_flatten)
#     18050    0.437    0.000    0.998    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/convert.py:78(recurse)
#   1216246    0.324    0.000    0.865    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/abc.py:117(__instancecheck__)
#     90250    0.431    0.000    0.844    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:915(of)
#     35508    0.135    0.000    0.832    0.000 <__array_function__ internals>:177(any)
#   1252488    0.765    0.000    0.765    0.000 {method 'match' of 're.Pattern' objects}
#     53558    0.177    0.000    0.708    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#     18050    0.047    0.000    0.565    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/reducers.py:551(<listcomp>)
#   1216246    0.541    0.000    0.541    0.000 {built-in method _abc._abc_instancecheck}
#     35508    0.072    0.000    0.531    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2307(any)
#     36100    0.123    0.000    0.519    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_dtype.py:34(__str__)
#     53558    0.467    0.000    0.467    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     35508    0.035    0.000    0.431    0.000 <__array_function__ internals>:177(norm)
#    626244    0.429    0.000    0.429    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/json/decoder.py:343(raw_decode)
#     36100    0.124    0.000    0.389    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_dtype.py:344(_name_get)
#     18050    0.022    0.000    0.361    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:339(min)
#     35508    0.211    0.000    0.355    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/linalg/linalg.py:2357(norm)
#    544948    0.349    0.000    0.349    0.000 {method 'split' of 'str' objects}
#   1462189    0.346    0.000    0.346    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:278(layout)
#    156561    0.300    0.000    0.325    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:1511(find_caches)
#     18050    0.042    0.000    0.291    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2802(amin)
#     18050    0.056    0.000    0.278    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:347(argmin)
#     71016    0.063    0.000    0.276    0.000 <__array_function__ internals>:177(dot)
#     54150    0.054    0.000    0.247    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:97(asarray)
#     89658    0.202    0.000    0.202    0.000 {built-in method numpy.asarray}
#     36100    0.050    0.000    0.199    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_dtype.py:330(_name_includes_bit_suffix)
#    662344    0.195    0.000    0.195    0.000 {method 'startswith' of 'str' objects}
#    106524    0.180    0.000    0.180    0.000 {built-in method numpy.array}
#    544948    0.169    0.000    0.169    0.000 {method 'replace' of 'str' objects}
#    156561    0.136    0.000    0.164    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py:322(layout)
#    544948    0.162    0.000    0.162    0.000 {built-in method sys._getframe}
#     36100    0.057    0.000    0.149    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#     18050    0.040    0.000    0.149    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1223(argmin)
#   1252488    0.141    0.000    0.141    0.000 {method 'end' of 're.Match' objects}
#     18050    0.030    0.000    0.138    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:523(maybe_wrap_like)
#     90250    0.075    0.000    0.136    0.000 {built-in method builtins.any}
#     18050    0.072    0.000    0.132    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/structure.py:2889(transform)
#    752594    0.110    0.000    0.110    0.000 {built-in method builtins.len}
#     18050    0.024    0.000    0.109    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#     18050    0.052    0.000    0.105    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:477(behaviorof)
#     54150    0.062    0.000    0.092    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:879(is_cupy_buffer)
#     72200    0.060    0.000    0.088    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#     54150    0.085    0.000    0.085    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    156561    0.052    0.000    0.081    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/partition.py:22(first)
#    156561    0.080    0.000    0.080    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:192(__init__)
#     18050    0.079    0.000    0.079    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#    269566    0.070    0.000    0.070    0.000 {built-in method builtins.issubclass}
#     35508    0.069    0.000    0.069    0.000 {method 'dot' of 'numpy.ndarray' objects}
#    126350    0.053    0.000    0.061    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:937(<genexpr>)
#     90250    0.040    0.000    0.054    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:868(is_numpy_buffer)
#     53558    0.050    0.000    0.050    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#     54150    0.033    0.000    0.045    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:891(is_jax_buffer)
#     36100    0.043    0.000    0.043    0.000 {method 'format' of 'str' objects}
#    108300    0.042    0.000    0.042    0.000 {method 'partition' of 'str' objects}
#     18050    0.011    0.000    0.035    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/structure.py:2874(maybe_fillna)
#     90250    0.034    0.000    0.034    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:17(instance)
#     13622    0.033    0.000    0.033    0.000 /tmp/ipykernel_1306/1682533672.py:1(distance)
#     35508    0.031    0.000    0.031    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     18050    0.021    0.000    0.027    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/operations/reducers.py:541(reduce)
#    108304    0.027    0.000    0.027    0.000 {built-in method builtins.getattr}
#     18050    0.019    0.000    0.025    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:1312(transform_child_layouts)
#     35508    0.024    0.000    0.024    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2302(_any_dispatcher)
#     35508    0.015    0.000    0.021    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/linalg/linalg.py:117(isComplexType)
#     36100    0.020    0.000    0.020    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/_dtype.py:24(_kind_name)
#     54150    0.019    0.000    0.019    0.000 {method 'get' of 'dict' objects}
#     71016    0.015    0.000    0.015    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/multiarray.py:736(dot)
#     53558    0.015    0.000    0.015    0.000 {method 'items' of 'dict' objects}
#     36100    0.014    0.000    0.014    0.000 {method 'upper' of 'str' objects}
#     36100    0.012    0.000    0.012    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/nplike.py:494(ma)
#     36100    0.009    0.000    0.009    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1219(_argmin_dispatcher)
#     36100    0.009    0.000    0.009    0.000 {method 'add' of 'set' objects}
#     36100    0.009    0.000    0.009    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2797(_amin_dispatcher)
#     35508    0.008    0.000    0.008    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/numpy/linalg/linalg.py:2353(_norm_dispatcher)
#     36104    0.007    0.000    0.007    0.000 {built-in method builtins.next}
#     36100    0.007    0.000    0.007    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/awkward/_util.py:516(maybe_wrap)
#     36100    0.007    0.000    0.007    0.000 {built-in method builtins.iter}
#      2217    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#     35/11    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/abc.py:121(__subclasscheck__)
#     35/11    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/codeop.py:142(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/traitlets/traitlets.py:692(__get__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/contextlib.py:261(helper)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/contextlib.py:86(__init__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/hooks.py:103(__call__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/traitlets/traitlets.py:654(get)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/contextlib.py:114(__enter__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/contextlib.py:123(__exit__)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_1306/2534407993.py:5(<module>)
#         4    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/compilerop.py:166(extra_flags)
#        32    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/_collections_abc.py:262(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3338(compare)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1278(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# !pip install snakeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: snakeviz in /eos/home-a/aperego/.local/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: tornado>=2.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages (from snakeviz) (6.1)
# DEPRECATION: gosam 2.1.1-4b98559 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gosam or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: professor2 X.Y.Z has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of professor2 or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# %load_ext snakeviz
# %snakeviz compute_residuals_r2s()
# Out:
#
# *** Profile stats marshalled to file '/tmp/tmpos3yyj8y'.
# Embedding SnakeViz in this document...
# <function display at 0x7fc25e5ca790>
# <iframe id='snakeviz-5b5579c8-cf7a-11ee-a390-0242ac11000b' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-5b5579c8-cf7a-11ee-a390-0242ac11000b").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/%2Ftmp%2Ftmpos3yyj8y")</script>

# %%
from numba import njit, prange

@njit
def distance_numba(x1,y1,z1,x2,y2,z2):
    return ((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)**0.5

@njit
def dot_numba(x, y):
    s = 0
    for i in range(len(x)):
        s += x[i]*y[i]
    return s

@njit 
def distance_numba(x1,y1,z1,x2,y2,z2):
    return ((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)**0.5

@njit
def minNumba(arr):
    if len(arr) == 0:
        raise ValueError("argmin: array is empty")

    min_value = arr[0]

    for i in range(1, len(arr)):
        if arr[i] < min_value:
            min_value = arr[i]

    return min_value

@njit
def project_lc_to_pca_numba(point, segment_start, segment_end):
    """
    `lc` is a 1D NumPy array of length 3 representing the point;
    `segment_start` and `segment_end` are 1D NumPy arrays of length 3 representing the start and end points of the line segment. 
    The function returns the minimum distance between the point and the line segment and the closest point on this segment.
    """
    segment_vector = segment_end - segment_start
    #print(segment_vector)
    point_vector = point - segment_start
    #print(point_vector)
    if not np.any(segment_vector):
        projection = 0
    else:
        projection = dot_numba(point_vector, segment_vector) / dot_numba(segment_vector, segment_vector)

    closest_point = segment_start + projection * segment_vector
    return np.linalg.norm(point - closest_point), closest_point

@njit
def computeCaloTime_numba(ev, vx, vy, vz, vt, vi, LChitTime, bx, by, bz, NMIN =3, MR=3):
    n_ts = 0
    time_ts = 0
    for i, t in enumerate(vt):
        nHitsWithTime = LChitTime[vi[i]]
        if t != -99 and project_lc_to_pca_numba(np.array([vx[i], vy[i], vz[i]]), np.array([0.,0.,0.]), np.array([bx, by, bz]))[0] < MR and nHitsWithTime >= NMIN:
            n_ts+=1
            if np.abs(bz)< np.abs(vz[i]):
                time_ts += t - distance_numba(bx, by, bz, vx[i], vy[i], vz[i])/C
            else:
                time_ts += t + distance_numba(bx, by, bz, vx[i], vy[i], vz[i])/C
    if n_ts == 0:
        return -99.
    else:
        return time_ts/n_ts
    return -99.

def compute_residuals_r2s_v2(NMIN = 3):
    residui=[]
    for ev, (recoToSim_index_ev, recoToSim_score_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev, LChitTime) in enumerate(zip(assoc_reco2sim.tsCLUE3D_recoToSim_SC, 
    assoc_reco2sim.tsCLUE3D_recoToSim_SC_score, ts3D.barycenter_x, ts3D.barycenter_y, ts3D.barycenter_z, ts3D.vertices_x, ts3D.vertices_y, ts3D.vertices_z, ts3D.vertices_time, 
    ts3D.vertices_indexes, cluster_hits_with_time)):
        for r2s_score, r2s_idx, bx, by, bz, vx, vy, vz, vt, vi in zip(recoToSim_score_ev, recoToSim_index_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev):
            t = computeCaloTime_numba(ev, vx, vy, vz, vt, vi, LChitTime, bx, by, bz, NMIN)
            si = r2s_idx[np.argmin(r2s_score)]
            boundt = SC_boundary_time[ev][si]
            if np.min(r2s_score) < 0.35 and boundt != -99 and t != -99:
                boundx = SC_boundx[ev][si]
                boundy = SC_boundy[ev][si]
                boundz = SC_boundz[ev][si]
                deltaT = t - boundt
                deltaS = distance(boundx, boundy, boundz, bx, by, bz)
                results = deltaT - deltaS / C
                residui.append(results)
    return residui

# %%
res2 = compute_residuals_r2s_v2()

# %%
import cProfile 
cProfile.run('compute_residuals_r2s_v2()', sort='cumtime')
# Out:
#          39624607 function calls (38451585 primitive calls) in 56.166 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   56.166   56.166 {built-in method builtins.exec}
#         1    0.000    0.000   56.166   56.166 <string>:1(<module>)
#         1    1.390    1.390   56.166   56.166 1299398470.py:68(compute_residuals_r2s_v2)
#    108300    0.282    0.000   28.072    0.000 dispatcher.py:724(typeof_pyval)
# 398100/108300    0.694    0.000   27.772    0.000 typeof.py:32(typeof)
# 398100/108300    0.661    0.000   27.471    0.000 functools.py:883(wrapper)
#    108300    0.097    0.000   26.980    0.000 __init__.py:64(typeof_Array)
#    108300    0.651    0.000   26.884    0.000 highlevel.py:1436(numba_type)
#     90750    0.845    0.000   23.139    0.000 arrayview.py:314(fromarray)
# 181500/90750    0.756    0.000   12.838    0.000 layout.py:52(typeof)
#     90750    0.922    0.000   12.736    0.000 layout.py:145(typeof_NumpyArray)
# 175772/175762    1.666    0.000   11.100    0.000 highlevel.py:1071(__getattr__)
#    380550    1.066    0.000    9.116    0.000 abstract.py:60(__call__)
#    253462    0.508    0.000    8.580    0.000 _util.py:505(wrap)
#    175772    8.043    0.000    8.043    0.000 {built-in method builtins.dir}
#    156561    1.181    0.000    7.923    0.000 highlevel.py:197(__init__)
#    191011    0.664    0.000    7.427    0.000 highlevel.py:545(__iter__)
#     67462    0.619    0.000    6.999    0.000 highlevel.py:578(__getitem__)
#     90750    0.868    0.000    6.616    0.000 arrayview.py:31(__init__)
#    156561    0.269    0.000    5.280    0.000 highlevel.py:352(behavior)
#    156561    2.034    0.000    5.011    0.000 _util.py:222(arrayclass)
# 72200/36100    0.169    0.000    4.810    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     36100    0.052    0.000    4.729    0.000 highlevel.py:1417(__array_function__)
#     36100    0.101    0.000    4.677    0.000 _numpy.py:31(array_function)
# 533024/465562    0.404    0.000    4.475    0.000 {built-in method builtins.hasattr}
#     90750    0.435    0.000    3.783    0.000 typeof.py:241(_typeof_ndarray)
#    626244    0.802    0.000    3.528    0.000 __init__.py:299(loads)
# 36100/18050    0.083    0.000    3.502    0.000 <__array_function__ internals>:177(argmin)
#     18050    0.166    0.000    3.333    0.000 reducers.py:691(argmin)
#    362500    1.644    0.000    3.308    0.000 nplike.py:915(of)
#    181500    0.843    0.000    3.222    0.000 npytypes.py:426(__init__)
#   7180430    2.115    0.000    2.902    0.000 {built-in method builtins.isinstance}
#     90750    0.186    0.000    2.544    0.000 arrayview.py:80(tolookup)
#    380550    0.495    0.000    2.498    0.000 abstract.py:48(_intern)
#    626244    1.114    0.000    2.485    0.000 decoder.py:332(decode)
#     90750    0.720    0.000    2.346    0.000 layout.py:508(tolookup)
#    616200    0.565    0.000    2.056    0.000 {method 'get' of 'dict' objects}
#    181500    1.275    0.000    2.044    0.000 common.py:49(__init__)
#    253700    0.443    0.000    2.042    0.000 convert.py:1859(to_layout)
#     90750    0.267    0.000    2.032    0.000 convert.py:1942(regularize_numpyarray)
#     18050    0.125    0.000    2.016    0.000 structure.py:2791(fill_none)
#    108300    0.185    0.000    1.885    0.000 arrayview.py:378(typeof_ArrayView)
#     90750    0.402    0.000    1.517    0.000 layout.py:575(__init__)
# 36100/18050    0.054    0.000    1.385    0.000 <__array_function__ internals>:177(amin)
#    175762    0.959    0.000    1.329    0.000 _util.py:74(exception_suffix)
#     18050    0.081    0.000    1.230    0.000 reducers.py:501(min)
#     90750    0.092    0.000    1.179    0.000 arrayview.py:68(<listcomp>)
#    181500    0.744    0.000    1.087    0.000 arrayview.py:51(arrayptr)
#     18050    0.066    0.000    1.076    0.000 convert.py:42(from_numpy)
#     36100    0.246    0.000    1.007    0.000 _util.py:564(completely_flatten)
#     18050    0.435    0.000    0.998    0.000 convert.py:78(recurse)
#    398100    0.514    0.000    0.966    0.000 functools.py:817(dispatch)
#     90750    0.124    0.000    0.912    0.000 __init__.py:183(dumps)
# 562050/380550    0.422    0.000    0.866    0.000 abstract.py:117(__hash__)
#    199550    0.492    0.000    0.821    0.000 _util.py:477(behaviorof)
#    108300    0.452    0.000    0.814    0.000 arrayview.py:391(__init__)
#     90750    0.248    0.000    0.788    0.000 encoder.py:182(encode)
#    987274    0.290    0.000    0.786    0.000 abc.py:117(__instancecheck__)
#     90750    0.098    0.000    0.757    0.000 _util.py:1214(recursively_apply)
#   1252488    0.736    0.000    0.736    0.000 {method 'match' of 're.Pattern' objects}
#    144900    0.140    0.000    0.733    0.000 nplike.py:97(asarray)
#    181500    0.172    0.000    0.702    0.000 nplike.py:93(array)
#     90750    0.248    0.000    0.659    0.000 _util.py:1223(transform)
#    108800    0.156    0.000    0.641    0.000 _util.py:523(maybe_wrap_like)
#    380050    0.416    0.000    0.625    0.000 abstract.py:120(__eq__)
#    144900    0.593    0.000    0.593    0.000 {built-in method numpy.asarray}
#     18050    0.047    0.000    0.570    0.000 reducers.py:551(<listcomp>)
#    181500    0.530    0.000    0.530    0.000 {built-in method numpy.array}
#     36100    0.122    0.000    0.520    0.000 _dtype.py:34(__str__)
#    987274    0.497    0.000    0.497    0.000 {built-in method _abc._abc_instancecheck}
#     90750    0.485    0.000    0.485    0.000 encoder.py:204(iterencode)
#     18050    0.067    0.000    0.475    0.000 nplike.py:347(argmin)
#    326400    0.332    0.000    0.475    0.000 nplike.py:879(is_cupy_buffer)
#    108300    0.148    0.000    0.463    0.000 __init__.py:10(register_and_check)
#     90750    0.085    0.000    0.446    0.000 nplike.py:101(ascontiguousarray)
#    362500    0.298    0.000    0.428    0.000 {built-in method builtins.any}
#    626244    0.424    0.000    0.424    0.000 decoder.py:343(raw_decode)
# 562050/380550    0.259    0.000    0.406    0.000 {built-in method builtins.hash}
#     36100    0.122    0.000    0.392    0.000 _dtype.py:344(_name_get)
#    235150    0.389    0.000    0.389    0.000 {method 'format' of 'str' objects}
#     18050    0.376    0.000    0.376    0.000 1299398470.py:50(computeCaloTime_numba)
#    398100    0.199    0.000    0.370    0.000 <string>:1(<lambda>)
#     18050    0.023    0.000    0.367    0.000 nplike.py:339(min)
#     90750    0.361    0.000    0.361    0.000 {built-in method numpy.ascontiguousarray}
#    398100    0.357    0.000    0.357    0.000 weakref.py:415(__getitem__)
#     90750    0.116    0.000    0.330    0.000 arrayview.py:47(<listcomp>)
#    156561    0.295    0.000    0.321    0.000 _util.py:1511(find_caches)
#    108300    0.284    0.000    0.315    0.000 __init__.py:36(register)
#     90750    0.082    0.000    0.303    0.000 arrayview.py:71(<listcomp>)
#     18050    0.043    0.000    0.296    0.000 fromnumeric.py:2802(amin)
#   1206344    0.295    0.000    0.295    0.000 {built-in method builtins.len}
#     18050    0.063    0.000    0.289    0.000 fromnumeric.py:1223(argmin)
#     90750    0.238    0.000    0.289    0.000 convert.py:1961(getfunction)
#    181500    0.177    0.000    0.272    0.000 <frozen importlib._bootstrap>:398(parent)
#     90750    0.267    0.000    0.267    0.000 _internal.py:250(__init__)
#    326400    0.193    0.000    0.259    0.000 nplike.py:891(is_jax_buffer)
#     18050    0.056    0.000    0.254    0.000 fromnumeric.py:69(_wrapreduction)
#    543500    0.253    0.000    0.253    0.000 npytypes.py:461(key)
#    362500    0.178    0.000    0.242    0.000 nplike.py:868(is_numpy_buffer)
#     18050    0.026    0.000    0.226    0.000 fromnumeric.py:51(_wrapfunc)
#    181500    0.221    0.000    0.221    0.000 arrayview.py:57(sharedptr)
#    181500    0.199    0.000    0.215    0.000 arrayview.py:38(find)
#     90750    0.181    0.000    0.213    0.000 layout.py:250(tolookup_identities)
#    652800    0.209    0.000    0.209    0.000 {method 'partition' of 'str' objects}
#    181500    0.114    0.000    0.206    0.000 misc.py:52(unliteral)
#     36100    0.051    0.000    0.204    0.000 _dtype.py:330(_name_includes_bit_suffix)
#     18050    0.193    0.000    0.193    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#    662344    0.189    0.000    0.189    0.000 {method 'startswith' of 'str' objects}
#    688217    0.177    0.000    0.177    0.000 highlevel.py:278(layout)
#     18050    0.176    0.000    0.176    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    156561    0.146    0.000    0.174    0.000 highlevel.py:322(layout)
#    398100    0.171    0.000    0.171    0.000 {built-in method __new__ of type object at 0x7fc269567980}
#    652800    0.159    0.000    0.159    0.000 {built-in method builtins.getattr}
#    175762    0.159    0.000    0.159    0.000 {method 'split' of 'str' objects}
#     36100    0.057    0.000    0.154    0.000 numerictypes.py:356(issubdtype)
#    380550    0.150    0.000    0.150    0.000 abstract.py:92(__init__)
#    362500    0.147    0.000    0.147    0.000 nplike.py:17(instance)
#    778650    0.140    0.000    0.140    0.000 abstract.py:95(key)
#   1252488    0.135    0.000    0.135    0.000 {method 'end' of 're.Match' objects}
#     18050    0.074    0.000    0.134    0.000 structure.py:2889(transform)
#     90750    0.102    0.000    0.133    0.000 numpy_support.py:86(from_dtype)
#     90750    0.131    0.000    0.131    0.000 arrayview.py:363(__init__)
#    398600    0.122    0.000    0.130    0.000 nplike.py:937(<genexpr>)
#     90750    0.129    0.000    0.129    0.000 numpy_support.py:222(map_layout)
#    108800    0.099    0.000    0.127    0.000 _util.py:1312(transform_child_layouts)
#    108300    0.042    0.000    0.097    0.000 __init__.py:77(repr_behavior)
#    181500    0.096    0.000    0.096    0.000 {method 'rpartition' of 'str' objects}
#    398100    0.095    0.000    0.095    0.000 {built-in method _abc.get_cache_token}
#     72200    0.064    0.000    0.092    0.000 numerictypes.py:282(issubclass_)
#     54150    0.089    0.000    0.089    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    216600    0.084    0.000    0.084    0.000 {built-in method builtins.repr}
#    156561    0.055    0.000    0.084    0.000 partition.py:22(first)
#    175762    0.083    0.000    0.083    0.000 {method 'replace' of 'str' objects}
#    564267    0.083    0.000    0.083    0.000 {method 'append' of 'list' objects}
#    156561    0.078    0.000    0.078    0.000 _util.py:192(__init__)
#    175762    0.071    0.000    0.071    0.000 {built-in method sys._getframe}
#    198550    0.050    0.000    0.050    0.000 {built-in method builtins.issubclass}
#    181500    0.050    0.000    0.050    0.000 abstract.py:114(__repr__)
#     90750    0.046    0.000    0.046    0.000 _internal.py:304(data)
#     90750    0.035    0.000    0.035    0.000 typeof.py:164(_typeof_none)
#     18050    0.011    0.000    0.035    0.000 structure.py:2874(maybe_fillna)
#     18050    0.021    0.000    0.028    0.000 reducers.py:541(reduce)
#     90750    0.026    0.000    0.026    0.000 highlevel.py:333(behavior)
#    126850    0.025    0.000    0.025    0.000 _util.py:516(maybe_wrap)
#     90750    0.020    0.000    0.020    0.000 {built-in method builtins.callable}
#     36100    0.020    0.000    0.020    0.000 _dtype.py:24(_kind_name)
#     90750    0.018    0.000    0.018    0.000 {method 'join' of 'str' objects}
#     18050    0.017    0.000    0.017    0.000 fromnumeric.py:70(<dictcomp>)
#     36100    0.014    0.000    0.014    0.000 {method 'upper' of 'str' objects}
#     36100    0.012    0.000    0.012    0.000 nplike.py:494(ma)
#     36100    0.011    0.000    0.011    0.000 fromnumeric.py:1219(_argmin_dispatcher)
#     36100    0.009    0.000    0.009    0.000 {method 'add' of 'set' objects}
#     36100    0.009    0.000    0.009    0.000 fromnumeric.py:2797(_amin_dispatcher)
#     36600    0.007    0.000    0.007    0.000 {built-in method builtins.next}
#     36100    0.007    0.000    0.007    0.000 {built-in method builtins.iter}
#      2217    0.006    0.000    0.006    0.000 1682533672.py:1(distance)
#     18050    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
#       500    0.000    0.000    0.001    0.000 abstract.py:19(_autoincr)
#       500    0.000    0.000    0.001    0.000 abstract.py:27(_on_type_disposal)
#       500    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
@njit
def argminNumba(arr):
    if len(arr) == 0:
        raise ValueError("argmin: array is empty")

    min_index = 0
    min_value = arr[0]

    for i in range(1, len(arr)):
        if arr[i] < min_value:
            min_value = arr[i]
            min_index = i

    return min_index

# %%
@njit
def compute_residuals_r2s_v3(NMIN = 3):
    residui=[]
    for ev, (recoToSim_index_ev, recoToSim_score_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev, LChitTime) in enumerate(zip(assoc_reco2sim.tsCLUE3D_recoToSim_SC, 
    assoc_reco2sim.tsCLUE3D_recoToSim_SC_score, ts3D.barycenter_x, ts3D.barycenter_y, ts3D.barycenter_z, ts3D.vertices_x, ts3D.vertices_y, ts3D.vertices_z, ts3D.vertices_time, 
    ts3D.vertices_indexes, cluster_hits_with_time)):
        for r2s_score, r2s_idx, bx, by, bz, vx, vy, vz, vt, vi in zip(recoToSim_score_ev, recoToSim_index_ev, ts_bx_ev, ts_by_ev, ts_bz_ev, ts_vx_ev, ts_vy_ev, ts_vz_ev, ts_vt_ev, ts_vi_ev):
            t = computeCaloTime_numba(ev, vx, vy, vz, vt, vi, LChitTime, bx, by, bz, NMIN)
            si = r2s_idx[argminNumba(r2s_score)]
            boundt = SC_boundary_time[ev][si]
            if minNumba(r2s_score) < 0.35 and boundt != -99 and t != -99:
                boundx = SC_boundx[ev][si]
                boundy = SC_boundy[ev][si]
                boundz = SC_boundz[ev][si]
                deltaT = t - boundt
                deltaS = distance_numba(boundx, boundy, boundz, bx, by, bz)
                results = deltaT - deltaS / C
                residui.append(results)
    return residui

# %%
res3 = compute_residuals_r2s_v3()

# %%
import cProfile 
cProfile.run('compute_residuals_r2s_v3()', sort='cumtime')
# Out:
#          4 function calls in 0.047 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.047    0.047 {built-in method builtins.exec}
#         1    0.000    0.000    0.047    0.047 <string>:1(<module>)
#         1    0.047    0.047    0.047    0.047 429975968.py:1(compute_residuals_r2s_v3)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
